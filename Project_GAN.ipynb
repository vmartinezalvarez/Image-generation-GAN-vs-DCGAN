# %% [markdown]
# <a href="https://colab.research.google.com/github/vmartinezalvarez/Image-generation-GAN-vs-DCGAN/blob/master/Project_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generative Adversarial Network

# %% [markdown]
# ## What are GANs?
#
# The idea behind GANs is that you have two networks, a generator  $G$  and a discriminator  $D$, competing against each other. The generator makes fake data to pass to the discriminator. The discriminator also sees real data and predicts whether the data it receives is real or false. The generator is trained to fool the discriminator, it wants to output data that looks as close as possible to real data. And the discriminator is trained to figure out which data is real and which is fake. What ends up happening is that the generator learns to make data that is indistinguishable from real data to the discriminator
#
# During training, the *generator* progressively becomes better at creating images that look real, while the *discriminator* becomes better at telling them apart. The process reaches equilibrium when the *discriminator* can no longer distinguish real images from fakes.

# %% [markdown]
# ### Import TensorFlow and other libraries

# %%
from __future__ import absolute_import, division, print_function

# %%
# !pip install tensorflow-gpu==2.0.0-alpha0
import tensorflow as tf
# Out:
# Collecting tensorflow-gpu==2.0.0-alpha0
#   Downloading https://files.pythonhosted.org/packages/1a/66/32cffad095253219d53f6b6c2a436637bbe45ac4e7be0244557210dc3918/tensorflow_gpu-2.0.0a0-cp36-cp36m-manylinux1_x86_64.whl (332.1MB)
#     100% |████████████████████████████████| 332.1MB 50kB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.0.9)
# Collecting google-pasta>=0.1.2 (from tensorflow-gpu==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/8c/96/adbd4eafe72ce9b5ca6f168fbf109386e1b601f7c59926a11e9d7b7a5b44/google_pasta-0.1.4-py3-none-any.whl (51kB)
#     100% |████████████████████████████████| 61kB 22.3MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.14.6)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.11.0)
# Collecting tb-nightly<1.14.0a20190302,>=1.14.0a20190301 (from tensorflow-gpu==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/a9/51/aa1d756644bf4624c03844115e4ac4058eff77acd786b26315f051a4b195/tb_nightly-1.14.0a20190301-py3-none-any.whl (3.0MB)
#     100% |████████████████████████████████| 3.0MB 7.5MB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.0.7)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.2.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (3.7.0)
# Collecting tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 (from tensorflow-gpu==2.0.0-alpha0)
#   Downloading https://files.pythonhosted.org/packages/13/82/f16063b4eed210dc2ab057930ac1da4fbe1e91b7b051a6c8370b401e6ae7/tf_estimator_nightly-1.14.0.dev2019030115-py2.py3-none-any.whl (411kB)
#     100% |████████████████████████████████| 419kB 11.6MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.33.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (3.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-alpha0) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-alpha0) (40.8.0)
# Installing collected packages: google-pasta, tb-nightly, tf-estimator-nightly, tensorflow-gpu
# Successfully installed google-pasta-0.1.4 tb-nightly-1.14.0a20190301 tensorflow-gpu-2.0.0a0 tf-estimator-nightly-1.14.0.dev2019030115

# %%
# To generate GIFs
# !pip install imageio
# Out:
# Requirement already satisfied: imageio in /usr/local/lib/python3.6/dist-packages (2.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from imageio) (1.14.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio) (4.1.1)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->imageio) (0.46)

# %%
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow.keras.layers as layers
import time

from IPython import display

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Load and prepare the MNIST dataset to train the generator and the discriminator.

# %%
(train_images, train_labels), (_, _) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
train_images = train_images.reshape(train_images.shape[0],-1).astype('float32')
train_images = (train_images - 127.5) / 127.5 # Normalize the images to [-1, 1]
train_images.shape[0]
train_images.shape
# Out:
# (60000, 784)

# %%
BUFFER_SIZE = 60000
BATCH_SIZE = 256

# %%
# Batch and shuffle the data
train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# ## Create the models
# ### The Generator

# %%
def make_generator_model():
  
    model = tf.keras.Sequential()
    
    model.add(layers.Dense(256, use_bias=True, input_shape=(100,)))
    model.add(layers.LeakyReLU())
 
    model.add(layers.Dense(512, use_bias=True))
    model.add(layers.LeakyReLU())
    
    model.add(layers.Dense(1024, use_bias=True))
    model.add(layers.LeakyReLU())

    model.add(layers.Dense(784, use_bias=True, activation='tanh'))
  
    return model

# %%
generator = make_generator_model()

noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)

# print(generated_image.shape)

generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               25856
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               803600
# =================================================================
# Total params: 1,486,352
# Trainable params: 1,486,352
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### The Discriminator

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    
    model.add(layers.Dense(1024, use_bias=True, input_shape=(784,)))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))
 
    model.add(layers.Dense(512, use_bias=True))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))
    
    model.add(layers.Dense(256, use_bias=True))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(1))
     
    return model

# %%
discriminator = make_discriminator_model()
decision = discriminator(generated_image)
print (decision)

discriminator.summary()
# Out:
# tf.Tensor([[-0.07333566]], shape=(1, 1), dtype=float32)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 1024)              803840
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 1,460,225
# Trainable params: 1,460,225
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Define the loss and optimizers
#
# Define loss functions and optimizers for both models.

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %% [markdown]
# ### Discriminator loss
#
# This method quantifies how well the discriminator is able to distinguish real images from fakes. It compares the discriminator's predictions on real images to an array of 1s, and the discriminator's predictions on fake (generated) images to an array of 0s.

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %% [markdown]
# ### Generator loss
# The generator's loss quantifies how well it was able to trick the discriminator. Intuitively, if the generator is performing well, the discriminator will classify the fake images as real (or 1). Here, we will compare the disciminators decisions on the generated images to an array of 1s.

# %%
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# The discriminator and the generator optimizers are different since we will train two networks separately.

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %% [markdown]
# ### Save checkpoints

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %% [markdown]
# ## Define the training loop

# %%
EPOCHS = 200
noise_dim = 100
num_examples_to_generate = 25

seed = tf.random.normal([num_examples_to_generate, noise_dim])

# %% [markdown]
# The training loop begins with generator receiving a random seed as input. That seed is used to produce an image. The discriminator is then used to classify real images (drawn from the training set) and fakes images (produced by the generator). The loss is calculated for each of these models, and the gradients are used to update the generator and discriminator.

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      generated_images = generator(noise, training=True)

      real_output = discriminator(images, training=True)
      fake_output = discriminator(generated_images, training=True)

      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %%
def train(dataset, epochs):  
  for epoch in range(epochs):
    start = time.time()
    
    for image_batch in dataset:
      train_step(image_batch)

    # Produce images for the GIF as we go
    display.clear_output(wait=True)
    generate_and_save_images(generator,
                             epoch + 1,
                             seed)
    
    # Save the model every 15 epochs
    if (epoch + 1) % 15 == 0:
      checkpoint.save(file_prefix = checkpoint_prefix)
    
    print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))
    
  # Generate after the final epoch
  display.clear_output(wait=True)
  generate_and_save_images(generator,
                           epochs,
                           seed)

# %% [markdown]
# **Generate and save images**

# %%
# !mkdir -p MNIST_GAN_images

# %%
def generate_and_save_images(model, epoch, test_input):
  # Notice `training` is set to False. 
  # This is so all layers run in inference mode (batchnorm).
  predictions = model(test_input, training=False)

  fig = plt.figure(figsize=(5,5))
  
  for i in range(predictions.shape[0]):
      plt.subplot(5, 5, i+1)
      imagen = predictions[i].numpy().reshape((28,28))
      plt.imshow(imagen * 127.5 + 127.5, cmap='gray')
      plt.axis('off')
        
  label = 'Epoch {0}'.format(epoch)
  fig.text(0.51, 0.05, label, ha='center',fontsize=14)
  plt.savefig('MNIST_GAN_images/image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %% [markdown]
# ## Train the model
# Call the `train()` method defined above to train the generator and discriminator simultaneously.
#
# At the beginning of the training, the generated images look like random noise. As training progresses, the generated digits will look increasingly real.

# %%
# %%time
train(train_dataset, EPOCHS)
# Out:
# CPU times: user 12min 58s, sys: 2min 21s, total: 15min 19s
# Wall time: 15min 8s

# %% [markdown]
# Restore the latest checkpoint.

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %% [markdown]
# ## Create a GIF

# %%
# Display a single image using the epoch number
def display_image(epoch_no):
  return PIL.Image.open('MNIST_GAN_images/image_at_epoch_{:04d}.png'.format(epoch_no))

# %%
display_image(EPOCHS)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=360x360 at 0x7FC3565E37B8>

# %% [markdown]
# Use `imageio` to create an animated gif using the images saved during training.

# %%
with imageio.get_writer('gan.gif', mode='I') as writer:
  filenames = glob.glob('MNIST_GAN_images/image*.png')
  filenames = sorted(filenames)
  last = -1
  for i,filename in enumerate(filenames):
    frame = 2*(i**0.5)
    if round(frame) > round(last):
      last = frame
    else:
      continue
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)
    
# A hack to display the GIF inside this notebook
os.rename('gan.gif', 'gan.gif.png')

# %% [markdown]
# Display the animated gif with all the mages generated during the training of GANs.

# %%
display.Image(filename="gan.gif.png")

# %%
# !zip -r /content/file.zip /content/MNIST_GAN_images
# Out:
#   adding: content/MNIST_GAN_images/ (stored 0%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0175.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0036.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0057.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0052.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0008.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0039.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0042.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0083.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0024.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0195.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0132.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0184.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0043.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0037.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0079.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0028.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0110.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0041.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0180.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0012.png (deflated 4%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0155.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0103.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0163.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0115.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0158.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0026.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0197.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0055.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0113.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0194.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0199.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0011.png (deflated 4%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0148.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0131.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0091.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0192.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0045.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0064.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0151.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0006.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0106.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0016.png (deflated 4%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0013.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0063.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0040.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0164.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0004.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0136.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0077.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0142.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0121.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0066.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0171.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0159.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0085.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0128.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0133.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0141.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0144.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0135.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0080.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0183.png (deflated 7%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0003.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0022.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0188.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0015.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0033.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0138.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0046.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0002.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0134.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0035.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0070.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0168.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0112.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0165.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0193.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0125.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0196.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0116.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0084.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0050.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0114.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0178.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0170.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0034.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0051.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0088.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0062.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0157.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0149.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0120.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0074.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0109.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0069.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0001.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0126.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0049.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0038.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0098.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0065.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0177.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0182.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0075.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0073.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0094.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0047.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0176.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0092.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0090.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0082.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0129.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0167.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0145.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0101.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0067.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0009.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0095.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0086.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0100.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0174.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0143.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0150.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0044.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0081.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0139.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0048.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0186.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0119.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0172.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0181.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0005.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0160.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0154.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0105.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0096.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0025.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0017.png (deflated 4%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0068.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0124.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0161.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0104.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0140.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0032.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0169.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0179.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0147.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0189.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0072.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0097.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0146.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0107.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0020.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0007.png (deflated 4%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0130.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0010.png (deflated 4%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0127.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0076.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0156.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0108.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0166.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0054.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0187.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0185.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0018.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0014.png (deflated 4%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0031.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0059.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0117.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0200.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0152.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0030.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0023.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0099.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0137.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0029.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0102.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0111.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0060.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0056.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0053.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0093.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0089.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0027.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0061.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0122.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0087.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0191.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0198.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0123.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0118.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0153.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0019.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0078.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0190.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0162.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0021.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0058.png (deflated 6%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0173.png (deflated 5%)
#   adding: content/MNIST_GAN_images/image_at_epoch_0071.png (deflated 5%)

# %%
from google.colab import files
files.download("/content/file.zip")
